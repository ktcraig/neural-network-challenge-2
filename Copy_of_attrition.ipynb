# %% [markdown]
# <a href="https://colab.research.google.com/github/ktcraig/neural-network-challenge-2/blob/main/Copy_of_attrition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from tensorflow.keras import layers, models, Model
from tensorflow.keras import layers
# !pip install --upgrade scikit-learn

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
# ...
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# ...

# %%
# Determine the number of unique values in each column
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']]
y_df.head()
# Out:
#   Attrition              Department
# 0       Yes                   Sales
# 1        No  Research & Development
# 2       Yes  Research & Development
# 3        No  Research & Development
# 4        No  Research & Development

# %%
# Create a list of at least 10 column names to use as X data
x = ['Age',
     'BusinessTravel',
     'Department',
     'DistanceFromHome',
     'Education',
     'EducationField',
     'EnvironmentSatisfaction',
     'HourlyRate',
     'JobInvolvement',
     'JobLevel']

# Create X_df using your selected columns
X_df = attrition_df[x]

# Show the data types for X_df
X_df.head()
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0   41      Travel_Rarely                   Sales                 1
# 1   49  Travel_Frequently  Research & Development                 8
# 2   37      Travel_Rarely  Research & Development                 2
# 3   33  Travel_Frequently  Research & Development                 3
# 4   27      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  JobLevel
# 0               3         2
# 1               2         2
# 2               2         1
# 3               3         1
# ...

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, test_size=0.2, random_state=42)

# %%
# Convert your X data to numeric data types however you see fit
# Add new code cells as necessary

# Import dependencies
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

# Create a OneHotEncoder instance
"""Source code: Assistance from colab assist"""
# Replace 'sparse' with 'sparse_output'
encoder = OneHotEncoder(sparse_output=False, drop='first')

# Select categorical columns that need to be encoded
categorical_cols = ['BusinessTravel', 'Department', 'EducationField']

# Create a copy of X_df to avoid modifying the original DataFrame
X_df_encoded = X_df.copy()

# Fit and transform the OneHotEncoder using the categorical columns
# Use the copy of X_df for encoding
encoded_cols = encoder.fit_transform(X_df_encoded[categorical_cols])

# Create a DataFrame with the encoded columns
encoded_df = pd.DataFrame(encoded_cols, columns=encoder.get_feature_names_out(categorical_cols))

# Drop original categorical columns from the copy of X_df
X_df_encoded = X_df_encoded.drop(categorical_cols, axis=1)

# Concatenate the encoded columns with the copy of the original DataFrame
X_df_encoded = pd.concat([X_df_encoded.reset_index(drop=True), encoded_df.reset_index(drop=True)], axis=1)

# Show the updated data types for X_df_encoded
print(X_df_encoded.dtypes)

# Use X_df_encoded for further processing
X_df = X_df_encoded # Assign the encoded DataFrame back to X_df if needed
# Out:
# Age                                    int64
# DistanceFromHome                       int64
# Education                              int64
# EnvironmentSatisfaction                int64
# HourlyRate                             int64
# JobInvolvement                         int64
# JobLevel                               int64
# BusinessTravel_Travel_Frequently     float64
# BusinessTravel_Travel_Rarely         float64
# Department_Research & Development    float64
# Department_Sales                     float64
# EducationField_Life Sciences         float64
# EducationField_Marketing             float64
# EducationField_Medical               float64
# EducationField_Other                 float64
# EducationField_Technical Degree      float64
# dtype: object

# %%
# Create a Standard Scaler
scaler = StandardScaler()

# Fit the StandardScaler to the training data
X_scaler = scaler.fit(X_df)

# Scale the training and testing data
X_scaled = X_scaler.transform(X_df)

# %%
from sklearn.preprocessing import OneHotEncoder

# Create a OneHotEncoder for the Department column
encoder = OneHotEncoder(sparse_output=False, drop='first')

# Fit the encoder to the training data
encoder.fit(y_df[['Department']])

# Create two new variables by applying the encoder to the training and testing data
y_train_encoded = encoder.transform(y_train[['Department']])
y_test_encoded = encoder.transform(y_test[['Department']])

# %%
# Create a OneHotEncoder for the Attrition column
encoder = OneHotEncoder(sparse_output=False, drop='first')

# Fit the encoder to the training data
encoder.fit(y_df[['Attrition']])

# Create two new variables by applying the encoder to the training and testing data
y_train_encoded = encoder.transform(y_train[['Attrition']])
y_test_encoded = encoder.transform(y_test[['Attrition']])

# %% [markdown]
# ## Part 2: Create, Compile, and Train the Model

# %%
# Find the number of columns in the X training data
num_features = X_train_array.shape[1]  # Get the number of features (16 in your case)

# Create the input layer with the correct shape
input_layer = layers.Input(shape=(num_features,), name='input_layer')

# Create at least 2 shared layers using Dense layers
shared_layer1 = layers.Dense(64, activation='relu')(input_layer)  # Example Dense layer
shared_layer2 = layers.Dense(32, activation='relu')(shared_layer1) # Example Dense layer

# %%
# Create a branch for 'Department' with a hidden layer and an output layer
# Create the hidden layer
# Create the output layer

department_dense = layers.Dense(64, activation='relu')(shared_layer1)

# Get the number of columns (classes) from the shape of y_train_encoded
department_output = layers.Dense(y_train_encoded.shape[1],
                             activation='sigmoid',
                             name='department_output')(department_dense) # Changed to department_dense

# %%
# Create a branch for 'Attrition' with a hidden layer and an output layer
# Create the hidden layer
# Create the output layer

attrition_dense = layers.Dense(64, activation='relu')(shared_layer1)

# Get the number of columns (classes) from the shape of y_train_encoded
attrition_output = layers.Dense(y_train_encoded.shape[1],
                             activation='sigmoid',
                             name='attrition_output')(attrition_dense)

# %%
# Create the model
"""Source code: Assistance from colab assist"""

model = Model(inputs=input_layer, outputs=[department_output, attrition_output])

# Compile the model
# Use the correct output layer names in the loss and metrics dictionaries
model.compile(optimizer='adam',
              loss={'department_output': 'categorical_crossentropy',  # Use 'department_oupt'
                    'attrition_output': 'categorical_crossentropy'},  # Use 'attrition_output'
              metrics={'department_output': 'accuracy',  # Use 'department_oupt'
                       'attrition_output': 'accuracy'})  # Use 'attrition_output'

# Summarize the model
model.summary()
# Out:
# Model: "functional_32"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 16)             │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_72 (Dense)          │ (None, 64)             │          1,088 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_74 (Dense)          │ (None, 64)             │          4,160 │ dense_72[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...

# %%
# Train the model
model.fit(
    X_train_array,
    {'department_output': y_train_encoded, 'attrition_output': y_train_encoded},
    epochs=10,
    batch_size=32,
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/losses/losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - attrition_output_accuracy: 0.6141 - attrition_output_loss: 0.0000e+00 - department_output_accuracy: 0.7976 - department_output_loss: 0.0000e+00 - loss: 0.0000e+00
# Epoch 2/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - attrition_output_accuracy: 0.8211 - attrition_output_loss: 0.0000e+00 - department_output_accuracy: 0.8211 - department_output_loss: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/10
# ...

# %%
# 1. Create a OneHotEncoder instance
encoder = OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore')  # handle_unknown='ignore' for unseen values in X_test

# 2. Fit the encoder on the categorical columns of X_train
categorical_cols = ['BusinessTravel', 'Department', 'EducationField']
encoder.fit(X_train[categorical_cols])
# Out:
# OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False)

# %%
# Evaluate the model with the testing data
"""Source code: Assistance from colab assist"""

# 1. Transform X_test using the fitted encoder
X_test_encoded = encoder.transform(X_test[categorical_cols]) # Encode categorical columns

# 2. Create a DataFrame with the encoded columns
X_test_encoded_df = pd.DataFrame(X_test_encoded, columns=encoder.get_feature_names_out(categorical_cols))

# 3. Drop original categorical columns from X_test
X_test_numeric = X_test.drop(categorical_cols, axis=1)

# 4. Concatenate the encoded columns with the numeric columns
X_test_final = pd.concat([X_test_numeric.reset_index(drop=True), X_test_encoded_df.reset_index(drop=True)], axis=1)

# 5. Convert X_test_final to a NumPy array with the correct data type (float32)
X_test_array = X_test_final.astype(np.float32).values

# Ensure that the dictionary keys match the output layer names
results = model.evaluate(X_test_array, {
    'department_output': y_test_encoded,
    'attrition_output': y_test_encoded,
})
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/losses/losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attrition_output_accuracy: 0.8447 - attrition_output_loss: 0.0000e+00 - department_output_accuracy: 0.8447 - department_output_loss: 0.0000e+00 - loss: 0.0000e+00

# %%
# Print the accuracy for both department and attrition
print(f"Department Accuracy: {results[3]}")
print(f"Attrition Accuracy: {results[3]}")
# Out:
# Department Accuracy: 0.8673469424247742
# Attrition Accuracy: 0.8673469424247742

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1. I believe that accuracy is the metric to use on this data because you are trying to determine how accurate you can predict how likely employees are to leave the company. I am skeptical of the results though because I may have used different columns than the original code and the numbers in the model are different than the original output in the starter code.
# 2. I used sigmoid activation. I used sigmoid activation because to predict accuracy I wanted an output ranging from 0 to 1.
# 3. I had a lot of issues with the different types of data within the initial dataframe that I could not resolve cleanly just through one hot encoder or standard scaler. In hindsight, I would select different columns from the dataframe to avoid so much processing later on in my code.
